# %% [markdown]
# ### Collect and Explore NBA Draft Data

# %% [markdown]
# ## Example

# %%
import pandas as pd

# 2009 Draft
html_2009 = pd.read_html('https://www.basketball-reference.com/draft/NBA_2009.html#stats', 
                         header =[1])
df_2009_draft = html_2009[0]
df_2009_draft = df_2009_draft[['Player', 'College', 'G', 'MP.1', 'PTS.1',
                               'TRB.1', 'AST.1', 'FG%', '3P%', 'FT%']]
df_2009_draft = df_2009_draft.dropna()

# Second round headers
df_2009_draft = df_2009_draft.drop([30, 31])
df_2009_draft
# Out:
#                Player                            College    G  MP.1 PTS.1  \
# 0       Blake Griffin                           Oklahoma  721  33.0  19.9
# 2        James Harden                      Arizona State  930  34.6  25.0
# 3        Tyreke Evans                            Memphis  594  30.7  15.7
# 5         Jonny Flynn                           Syracuse  163  22.9   9.2
# 6       Stephen Curry                           Davidson  826  34.3  24.3
# 7         Jordan Hill                            Arizona  409  18.8   7.9
# 8       DeMar DeRozan                                USC  946  34.2  20.7
# 10  Terrence Williams                         Louisville  153  19.1   7.1
# 11   Gerald Henderson                               Duke  535  25.9  11.2
# 12   Tyler Hansbrough                                UNC  428  16.9   6.7
# 13         Earl Clark                         Louisville  261  13.9   4.4
# 14        Austin Daye                            Gonzaga  293  14.1   5.2
# 15      James Johnson                        Wake Forest  739  20.6   7.8
# 16       Jrue Holiday                               UCLA  829  33.2  16.2
# 17          Ty Lawson                                UNC  551  29.2  12.7
# 18        Jeff Teague                        Wake Forest  826  26.8  12.2
# 19        Eric Maynor                                VCU  267  14.6   4.3
# 20    Darren Collison                               UCLA  711  29.3  12.5
# 23      Byron Mullens                         Ohio State  189  18.2   7.4
# 25         Taj Gibson                                USC  888  24.6   9.1
# 26    DeMarre Carroll                           Missouri  578  23.7   8.9
# 27    Wayne Ellington                                UNC  767  20.9   8.0
# 28      Toney Douglas                      Florida State  394  19.1   7.6
# 32         Jeff Ayres                      Arizona State  237   9.8   2.9
# 33    Jermaine Taylor                    Central Florida   65  12.1   5.4
# 34   Dante Cunningham                          Villanova  715  20.8   5.8
# 36     DaJuan Summers                         Georgetown   83   9.9   3.3
# 37          Sam Young                               Pitt  249  15.9   5.8
# 38       DeJuan Blair                               Pitt  424  16.6   6.8
# 39       Jon Brockman                         Washington  150  10.5   2.1
# 41      Derrick Brown                             Xavier  171  14.9   5.2
# 42        Jodie Meeks                           Kentucky  539  22.5   9.3
# 43   Patrick Beverley                           Arkansas  517  27.5   8.9
# 44    Marcus Thornton                                LSU  483  23.4  11.9
# 45     Chase Budinger                            Arizona  407  19.7   7.9
# 46      Nick Calathes                            Florida  129  15.6   4.6
# 47        Danny Green                                UNC  805  25.4   8.8
# 49     Taylor Griffin                           Oklahoma    8   4.0   1.3
# 53         A.J. Price                              UConn  261  15.1   5.8
# 56        Patty Mills                       Saint Mary's  808  20.7   9.2
# 59      Lester Hudson  University of Tennessee at Martin   57  10.4   4.7
#
#    TRB.1 AST.1   FG%   3P%   FT%
# 0    8.2   4.1  .493  .327  .696
# 2    5.6   6.7  .443  .362  .859
# 3    4.6   4.8  .440  .323  .757
# 5    1.9   3.9  .400  .338  .809
# 6    4.6   6.5  .473  .428  .908
# 7    5.8   0.8  .497  .136  .699
# 8    4.4   3.9  .464  .287  .836
# 10   3.6   2.4  .412  .317  .659
# 11   3.2   1.9  .440  .327  .793
# 12   4.2   0.4  .439  .136  .738
# 13   3.0   0.5  .403  .328  .664
# 14   2.6   0.7  .402  .351  .778
# 15   3.6   2.1  .475  .303  .679
# 16   4.0   6.4  .460  .363  .777
# 17   2.7   6.0  .460  .359  .770
# 18   2.4   5.6  .444  .360  .844
# 19   1.3   2.8  .392  .350  .721
# 20   2.7   5.0  .471  .394  .853
# 23   4.2   0.8  .408  .319  .706
# 25   6.1   1.0  .518  .244  .711
# 26   4.2   1.3  .430  .358  .741
# 27   2.1   1.1  .410  .383  .843
# 28   2.2   2.3  .404  .354  .824
# 32   2.7   0.4  .553  .400  .776
# 33   1.7   0.7  .441  .284  .730
# 34   3.7   0.7  .469  .345  .649
# 36   1.0   0.3  .384  .367  .642
# 37   2.3   0.7  .442  .280  .742
# 38   5.1   0.8  .524  .000  .608
# 39   3.1   0.3  .488  .000  .618
# 41   2.4   0.7  .515  .317  .637
# 42   2.1   1.1  .420  .373  .879
# 43   4.3   3.5  .415  .379  .759
# 44   2.8   1.4  .425  .358  .830
# 45   3.0   1.2  .430  .352  .797
# 46   1.9   2.7  .441  .288  .581
# 47   3.4   1.6  .421  .399  .806
# 49   0.3   0.1  .400  .000  .500
# 53   1.4   2.2  .380  .316  .742
# 56   1.7   2.3  .427  .391  .855
# 59   1.4   1.2  .375  .277  .806

# %% [markdown]
# ## All Data

# %%
html_2009 = pd.read_html('https://www.basketball-reference.com/draft/NBA_2009.html#stats')
df_2009_draft = html_2009[0]

html_2010 = pd.read_html('https://www.basketball-reference.com/draft/NBA_2010.html#stats')
df_2010_draft = html_2010[0]

html_2011 = pd.read_html('https://www.basketball-reference.com/draft/NBA_2011.html#stats')
df_2011_draft = html_2011[0]

html_2012 = pd.read_html('https://www.basketball-reference.com/draft/NBA_2012.html#stats')
df_2012_draft = html_2012[0]

html_2013 = pd.read_html('https://www.basketball-reference.com/draft/NBA_2013.html#stats')
df_2013_draft = html_2013[0]

html_2014 = pd.read_html('https://www.basketball-reference.com/draft/NBA_2014.html#stats')
df_2014_draft = html_2014[0]

html_2015 = pd.read_html('https://www.basketball-reference.com/draft/NBA_2015.html#stats')
df_2015_draft = html_2015[0]

html_2016 = pd.read_html('https://www.basketball-reference.com/draft/NBA_2016.html#stats')
df_2016_draft = html_2016[0]

html_2017 = pd.read_html('https://www.basketball-reference.com/draft/NBA_2017.html#stats')
df_2017_draft = html_2017[0]

html_2018 = pd.read_html('https://www.basketball-reference.com/draft/NBA_2018.html#stats')
df_2018_draft = html_2018[0]

html_2019 = pd.read_html('https://www.basketball-reference.com/draft/NBA_2019.html#stats')
df_2019_draft = html_2019[0]

html_2020 = pd.read_html('https://www.basketball-reference.com/draft/NBA_2020.html#stats')
df_2020_draft = html_2020[0]

html_2021 = pd.read_html('https://www.basketball-reference.com/draft/NBA_2021.html#stats')
df_2021_draft = html_2021[0]

df_2009_draft.head()

# %%
all_raw_dfs = [df_2009_draft, df_2010_draft, df_2011_draft, df_2012_draft,
              df_2013_draft, df_2014_draft, df_2015_draft, df_2016_draft,
              df_2017_draft, df_2018_draft, df_2019_draft, df_2020_draft,
              df_2021_draft]
